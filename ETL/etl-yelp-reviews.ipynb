# %%
import pandas as pd
# import pyarrow as pa
# import numpy as np

# %%
yelp_reviews = pd.read_parquet('../Yelp-Data/review.parquet')

# %%
yelp_business_fix = pd.read_parquet('../Yelp-Data/business-fixed.parquet')

# %% [markdown]
# Para la función de ETL de este parquet debería tener la lista de business_id dependiendo del negocio <br>
# Deberíamos asegurarnos que las columnas tenga sus tipos de datos especificos <br>
# Deberíamos borrar duplicados y nulos <br>

# %%
yelp_reviews.info()
yelp_reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        float64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 480.0+ MB
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# ...

# %%
yelp_business_fix.head()
# Out:
#               business_id                                    name  \
# 0  kfNv-JZpuN6TVNSO6hHdkw                         Hibachi Express
# 1  ljxNT9p0y7YMPx0fcNBGig     Tony's Restaurant & 3rd Street Cafe
# 2  aCDY7vXYMs54EbYuQScsnQ                39 North Taproom & Grill
# 3  CtMEJxpVMlNzFpB4PtFjfA                            Aussie Grill
# 4  Dtuf4vD0znzwJW9vk3iTNw  Tomo Japanese Steakhouse and Sushi Bar
#
#                       address          city state   latitude  longitude  \
# 0              6625 E 82nd St  Indianapolis    PA  39.904320 -86.053080
# 1                312 Piasa St         Alton    IL  38.896563 -90.186203
# 2          110 S MacDade Blvd     Glenolden    DE  39.903697 -75.294981
# 3    25340 Sierra Center Blvd          Lutz    AZ  28.192191 -82.396367
# 4  7411 N Keystone Ave, Ste A  Indianapolis    MO  39.888725 -86.121213
#
#    stars  review_count  is_open  \
# 0    4.0            20        1
# 1    3.0            94        1
# ...

# %%
yelp_buissnes_fix[yelp_buissnes_fix['name'] == 'Texas Roadhouse']

# %%
merged_df = yelp_reviews.merge(yelp_business_fix, on='business_id', how='inner')

# %%
merged_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  pUycOfUwM8vqX7KjRRhUEA  59MxRhNVhU9MYndMkz0wtw  gebiRewfieSdtt17PTW6Zg
# 1  _Ub20uO1MKy4XOVPOdzpqw  lUYboGI6aFbZ0dX27pijpA  gebiRewfieSdtt17PTW6Zg
# 2  -DjIfoNFAiT5J4kF9hXocQ  SrfDRvGKI8FQq9LCr0dQuQ  gebiRewfieSdtt17PTW6Zg
# 3  URe-2Zlv7RoY4Ycr9JYVWw  SfMf7DEX7xT82OCcbZFsgQ  gebiRewfieSdtt17PTW6Zg
# 4  tHP5ihPd_W9OzfkKEWdIwA  aH3AH7V9g60w4pt3LpJ1_Q  gebiRewfieSdtt17PTW6Zg
#
#    stars_x  useful  funny  cool  \
# 0      3.0       0      0     0
# 1      1.0       0      2     0
# 2      3.0       9      4     6
# 3      5.0       1      0     1
# 4      4.0       0      0     0
#
#                                                 text                 date  \
# 0  Had a party of 6 here for hibachi. Our waitres...  2016-07-25 07:31:06
# 1  Sat down over a half hour, only miso and drink...  2017-06-28 01:04:59
# 2  Not bad. Sushi roll was good but options were ...  2017-01-14 23:31:35
# ...

# %%
steak_df = merged_df[merged_df['name'].str.contains('Texas Roadhouse')]

# %%
steak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5402 entries, 10748 to 237143
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     5402 non-null   object
#  1   user_id       5402 non-null   object
#  2   business_id   5402 non-null   object
#  3   stars_x       5402 non-null   float64
#  4   useful        5402 non-null   int64
#  5   funny         5402 non-null   int64
#  6   cool          5402 non-null   int64
#  7   text          5402 non-null   object
#  8   date          5402 non-null   object
#  9   name          5402 non-null   object
#  10  address       5402 non-null   object
#  11  city          5402 non-null   object
#  12  state         5402 non-null   object
#  13  latitude      5402 non-null   float64
#  14  longitude     5402 non-null   float64
#  15  stars_y       5402 non-null   float64
#  16  review_count  5402 non-null   int64
#  17  is_open       5402 non-null   int64
# ...

# %%
steak_df[steak_df['business_id'] == 'T9n_LqUUhC2b1ALhg57Y5Q']
# Out:
#                     review_id                 user_id             business_id  \
# 10748  r0K3LE3H32LqhlLHFdnBxQ  345ZsXYJ0nnkqdz_ft0RLQ  T9n_LqUUhC2b1ALhg57Y5Q
# 10749  _NLZCZem4cIWMuIgZAIlRw  u4fVHPzmuMlu7gA0srl7xQ  T9n_LqUUhC2b1ALhg57Y5Q
# 10750  H0eZbmVLQHbM0dV6CbFOEQ  w8pAPcss3VQHt4PEBtXvXw  T9n_LqUUhC2b1ALhg57Y5Q
# 10751  n08oID_WhJ1Lf13Z-8HzGw  hWDz2MFSUUm4e8TeLWrEYA  T9n_LqUUhC2b1ALhg57Y5Q
# 10752  aaX8avbbfiAINilmancqNg  sOJvlksRkRHF8iYU_KbHbg  T9n_LqUUhC2b1ALhg57Y5Q
# ...                       ...                     ...                     ...
# 10998  zhkWd2A8Wnf6p4ZG0ygLXg  6KWMWMgd_zUuh0O_i5KREA  T9n_LqUUhC2b1ALhg57Y5Q
# 10999  uq28bd2RPpAs7Irmi_ebYA  pamPk2N-OrlMjrY_cFJN5Q  T9n_LqUUhC2b1ALhg57Y5Q
# 11000  k2v73Q5Qr9DDVCoUYKs1Kw  h8L_oYRfB_fhpwPM9-pgpQ  T9n_LqUUhC2b1ALhg57Y5Q
# 11001  d4jJl6N0Si-DGPM74PhENQ  byKsZhn1EVES3PHEhhbeUw  T9n_LqUUhC2b1ALhg57Y5Q
# 11002  D2fd1NF-zqA1uPCP-VIppA  QXYdE6EQiUOhKy1FpQSD7w  T9n_LqUUhC2b1ALhg57Y5Q
#
# ...

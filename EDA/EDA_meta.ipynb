# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
from Utils import helper as hp
warnings.filterwarnings('ignore')

# %%
meta_df = hp.merge_dataframes('drive-download',11)

# %%
print(meta_df.info())
meta_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   name              object
#  1   address           object
#  2   gmap_id           object
#  3   description       object
#  4   latitude          float64
#  5   longitude         float64
#  6   category          object
#  7   avg_rating        float64
#  8   num_of_reviews    int64
#  9   price             object
#  10  hours             object
#  11  MISC              object
#  12  state             object
#  13  relative_results  object
#  14  url               object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 346.2+ MB
# None
#                name                                            address
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...  \
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# ...

# %%
meta_overview = hp.data_overview(meta_df)
meta_overview
# Out:
#         nombre_campo                            tipo_datos  NO_nulos_%
# 0               name   [<class 'str'>, <class 'NoneType'>]      100.00  \
# 1            address   [<class 'str'>, <class 'NoneType'>]       97.34
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]        8.41
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.42
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]        9.10
# 10             hours  [<class 'list'>, <class 'NoneType'>]       73.97
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       77.16
# ...

# %%
print(meta_df.dtypes)
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Revisión de duplicados

meta_duplicated = meta_df[['name','address',  'description', 'latitude', 'longitude',  'num_of_reviews',  'price','avg_rating','gmap_id','state', 'url' ]]
meta_duplicated[meta_duplicated.duplicated()]
# Out:
#                      name                                            address
# 26573     Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...  \
# 26574        City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 26575        San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 26576        Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 26577    Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                   ...                                                ...
# 1650006   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1925007   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 2200008   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 2475009   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 2750010   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
#
# ...

# %%
# Revisión de Outliers
outliers_columns = ['avg_rating'] #aca no se si va igual

for column in outliers_columns:
    hp.outliers_percentage(meta_df, column)
    print("-"*66)
# Out:
# Total de outliers en avg_rating: 53956 de 3025011 registros -- 1.78 %
# ------------------------------------------------------------------

# %%
meta_df.to_parquet('meta_data.parquet')

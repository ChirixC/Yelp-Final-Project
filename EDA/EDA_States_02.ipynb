# %%
import pandas as pd
import numpy as np
import json
import ast
import re
from Utils import helper as hp
import pyarrow as pyarrow
import pyarrow.parquet as pq

# %% [markdown]
# Illinois

# %%
df_illinois = hp.merge_dataframes(r"data-states\review-Illinois",14)

# %%
hp.data_overview(df_illinois)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       56.56    43.44
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.78    97.22
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       12.15    87.85
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          912218
# 5         2041626
# 6         1844881
# 7               0

# %%
df_illinois.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        912218
# pics       2041626
# resp       1844881
# gmap_id          0
# dtype: int64

# %%
duplicados = df_illinois[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                 name           time  rating  \
# 82       105719181108978283236               K Gord  1531335836942       5
# 98       101593364133418938543           Luís Valle  1433381059160       5
# 99       110273110013610425293          Kris Wojtko  1392068406976       5
# 102      118246378331615494336    angela colclasure  1436286388044       5
# 109      108908028801034684896          Mike Strick  1566586867223       5
# ...                        ...                  ...            ...     ...
# 1916944  105088119171720077555          Jonid Imeri  1597219965555       5
# 1916945  118026642035419655270          Robbie King  1593884379053       4
# 1916946  111410583786345663244          marcos diaz  1605749780918       4
# 1916947  111615969220968257116  Marcello Ingargiola  1592966959606       5
# 2032939  109944309918597213691        Devonna Seals  1608164599626       5
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_illinois, column)
    print("-"*66)
# Out:
# Total de outliers en time: 18853 de 2100000 registros -- 0.9 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 2100000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Indiana

# %%
df_indiana = hp.merge_dataframes(r"data-states\review-Indiana",15)

# %%
hp.data_overview(df_indiana)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       55.13    44.87
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.10    97.90
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       12.40    87.60
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4         1009510
# 5         2202726
# 6         1971058
# 7               0

# %%
df_indiana.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text       1009510
# pics       2202726
# resp       1971058
# gmap_id          0
# dtype: int64

# %%
duplicados = df_indiana[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                name           time  rating  \
# 153      108987166009783498172        Ashley Clark  1480971694081       1
# 187      102157094898180364750          Amy Matzet  1525302604376       5
# 189      118231212133797630173           Kala Gill  1626897817659       5
# 192      106355179468738058308               Jenni  1452225954385       5
# 226      116193310403904778772         Veno Norris  1552608754604       1
# ...                        ...                 ...            ...     ...
# 1157300  111999823831053570337          Troy Hicks  1536626504281       5
# 1157301  106724399224224261193           John Teer  1577756985805       4
# 1157302  105984158140940496718      Jennifer Smith  1544143160409       5
# 1157303  103895793284567846586  Mercedes Krumwiede  1528030997217       5
# 1157304  112215481078460292151        T.R. Gooding  1561710601021       2
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_indiana, column)
    print("-"*66)
# Out:
# Total de outliers en time: 11274 de 2250000 registros -- 0.5 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 2250000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Iowa

# %%
df_iowa = hp.merge_dataframes(r"data-states\review-Iowa",18)

# %%
hp.data_overview(df_iowa)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       51.63    48.37
# 5         pics  [<class 'NoneType'>, <class 'list'>]        1.80    98.20
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       10.04    89.96
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4         1295176
# 5         2629534
# 6         2408942
# 7               0

# %%
df_iowa.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text       1295176
# pics       2629534
# resp       2408942
# gmap_id          0
# dtype: int64

# %%
duplicados = df_iowa[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id               name           time  rating  \
# 27       108486176434351331608       Frank Pagano  1597767140701       5
# 29       100982540186387219669         Shaany Bee  1589485693845       5
# 46       103629459536987979750    Kendra Brockman  1627928404556       1
# 160      106164210358292361085    Stephanie Coady  1538696254033       5
# 200      113787769881630839064        Brett Boote  1506128068950       4
# ...                        ...                ...            ...     ...
# 2516250  102924526347042795383      Pedro Castedo  1554775811264       5
# 2516291  109924347520287723458    David Haverkamp  1514685217323       4
# 2522595  100558948222143268936  Carolyn wise-mayo  1517364201570       5
# 2522599  116993740543710511093         Rob Bitter  1551217476759       5
# 2522602  108903335216382969800        Anna Cullen  1519271491730       5
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_iowa, column)
    print("-"*66)
# Out:
# Total de outliers en time: 12128 de 2677684 registros -- 0.45 %
# ------------------------------------------------------------------
# Total de outliers en rating: 110974 de 2677684 registros -- 4.14 %
# ------------------------------------------------------------------

# %% [markdown]
# Kansas

# %%
df_kansas = hp.merge_dataframes(r"data-states\review-Kansas",13)

# %%
hp.data_overview(df_kansas)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       53.82    46.18
# 5         pics  [<class 'NoneType'>, <class 'list'>]        1.96    98.04
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       11.97    88.03
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          900604
# 5         1911846
# 6         1716500
# 7               0

# %%
df_kansas.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        900604
# pics       1911846
# resp       1716500
# gmap_id          0
# dtype: int64

# %%
duplicados = df_kansas[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                      name           time  \
# 42       108986493109191321689         Spencer Steenblik  1557007420298
# 47       116469397458659119996  Rebecca Swinburne Romine  1626451409190
# 50       108158651845963851843             Julia Gaughan  1622562674382
# 51       112593912567201084108           Jennifer Jacobs  1613424284170
# 53       101622365557206179951                 sonia arb  1616710838398
# ...                        ...                       ...            ...
# 1710496  115663443750175282081              Leonard Dale  1549577344956
# 1710499  113953138613374531032               Greg Wilson  1497995947724
# 1713379  110933986475979272611           Steven Thompson  1546718123704
# 1713381  100347372766023639853                Emmer Alex  1531100549124
# 1713387  114881605765923224839            Josh Stockwell  1464970683808
#
#          rating                                               text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_kansas, column)
    print("-"*66)
# Out:
# Total de outliers en time: 9663 de 1950000 registros -- 0.5 %
# ------------------------------------------------------------------
# Total de outliers en rating: 87840 de 1950000 registros -- 4.5 %
# ------------------------------------------------------------------

# %% [markdown]
# Kentucky

# %%
df_kentucky = hp.merge_dataframes(r"data-states\review-Kentucky",11)

# %%
hp.data_overview(df_kentucky)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       54.13    45.87
# 5         pics  [<class 'NoneType'>, <class 'list'>]        1.97    98.03
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       11.79    88.21
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          756820
# 5         1617436
# 6         1455499
# 7               0

# %%
df_kentucky.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        756820
# pics       1617436
# resp       1455499
# gmap_id          0
# dtype: int64

# %%
duplicados = df_kentucky[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                       user_id                name           time  rating  \
# 20      103630699261510972728  Margaret E Gambrel  1578783753122       5
# 21      114451993173920779378        Sandra Frith  1551228371213       1
# 22      116736585121721491634    Bertie Robertson  1516780008741       3
# 93      108980494708640256888        Cheryl Basil  1615273584550       3
# 103     106127629787400631814                Cora  1619730204215       5
# ...                       ...                 ...            ...     ...
# 520861  102640768158384991234  Trisha Maddox Back  1529533220097       5
# 520862  115099283565614809583      Michael Hadley  1516472024878       5
# 520863  114425544329675330743       Heather Jones  1514832648185       4
# 521013  111352967406756757460       Nicole Lyvers  1524424214885       5
# 521014  106444757587473764736      Max McAllister  1537451092804       3
#
#                                                      text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_kentucky, column)
    print("-"*66)
# Out:
# Total de outliers en time: 6520 de 1650000 registros -- 0.4 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 1650000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Louisiana

# %%
df_louisiana = hp.merge_dataframes(r"data-states\review-Louisiana",10)

# %%
hp.data_overview(df_louisiana)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       52.61    47.39
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.38    97.62
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       10.68    89.32
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          710884
# 5         1464372
# 6         1339860
# 7               0

# %%
df_louisiana.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        710884
# pics       1464372
# resp       1339860
# gmap_id          0
# dtype: int64

# %%
duplicados = df_louisiana[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                       user_id             name           time  rating  \
# 95      118142041145317766391     ray shaffers  1621026659069       4
# 366     103429391963154573860      Robert Figy  1577054265583       4
# 391     107724780529421478369   Jenny Van Dyke  1599763245340       5
# 461     102542867966688846128     Scott Cabell  1461272305160       5
# 470     113264083543881557252    Calvin Guidry  1578441998834       5
# ...                       ...              ...            ...     ...
# 547798  118426767050773123986    Gezus Witagee  1489778464033       3
# 547800  112482079886212503992  Anthony Collins  1566987288983       3
# 547805  117318828480486949924  Phyllis Emilien  1466167662063       5
# 547857  101771380523461158161  Gerrit Lawrence  1495043764591       5
# 547858  103276214437914008621     Rhonda Wolfe  1480660766677       5
#
#                                                      text  \
# 95                                                   None
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_louisiana, column)
    print("-"*66)
# Out:
# Total de outliers en time: 6593 de 1500000 registros -- 0.44 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 1500000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Maine

# %%
df_maine = hp.merge_dataframes(r"data-states\review-Maine",8)

# %%
hp.data_overview(df_maine)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       54.65    45.35
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.86    97.14
# 6         resp  [<class 'NoneType'>, <class 'dict'>]        8.53    91.47
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          509681
# 5         1091696
# 6         1028050
# 7               0

# %%
df_maine.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        509681
# pics       1091696
# resp       1028050
# gmap_id          0
# dtype: int64

# %%
duplicados = df_maine[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id             name           time  rating  \
# 61       113883714555860720234  Michelle Dupuis  1565263187049       5
# 243      111538628713410895100    Ronald Valade  1478631595888       5
# 338      106508408571274568350   Alicia Rediker  1627397601234       5
# 341      105277354241800076815   Kolossus Prime  1625576779984       5
# 344      105226949161248700437    Katie McGrath  1622556756302       4
# ...                        ...              ...            ...     ...
# 1040232  110491093576718979749   Brian Wardwell  1470857141405       3
# 1040665  110472515524733746512   Michael Carter  1610890817436       5
# 1040668  106092983561456711120    Perks Advisor  1598703313378       4
# 1040691  112017097419294506865    Diane Leavitt  1531571671416       4
# 1040715  115614738560335367129   Wayne Emington  1543630457596       4
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_maine, column)
    print("-"*66)
# Out:
# Total de outliers en time: 4233 de 1123881 registros -- 0.38 %
# ------------------------------------------------------------------
# Total de outliers en rating: 37407 de 1123881 registros -- 3.33 %
# ------------------------------------------------------------------

# %% [markdown]
# Maryland

# %%
df_maryland = hp.merge_dataframes(r"data-states\review-Maryland",16)

# %%
hp.data_overview(df_maryland)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       55.27    44.73
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.64    97.36
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       12.68    87.32
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4         1073525
# 5         2336557
# 6         2095635
# 7               0

# %%
df_maryland.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text       1073525
# pics       2336557
# resp       2095635
# gmap_id          0
# dtype: int64

# %%
duplicados = df_maryland[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id             name           time  rating  \
# 62       104218779340892853929  Oluwadare Ajayi  1591037967356       4
# 139      116417604448537175784             Suzi  1510851475214       4
# 145      102852293019340471532    LaRane Garner  1511796627270       2
# 146      104088107548784266481      Jacob Cohen  1466155433442       5
# 195      108632908416837846229            Jamie  1621430014279       5
# ...                        ...              ...            ...     ...
# 2399698  102317160976984016181    J.T. Thornton  1574255291502       4
# 2399701  113569972300476153694          Dee Roy  1486844067549       5
# 2399702  113302539249224625798     Joseph Brown  1501018606190       5
# 2399710  105494329511524401418         Jon Jhon  1464776425134       5
# 2399731  117202668138267616330    Maacela Davis  1478781498790       5
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_maryland, column)
    print("-"*66)
# Out:
# Total de outliers en time: 15720 de 2400000 registros -- 0.66 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 2400000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Massachusetts

# %%
df_massachusetts = hp.merge_dataframes(r"data-states\review-Massachusetts",16)

# %%
hp.data_overview(df_massachusetts)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       53.00    47.00
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.90    97.10
# 6         resp  [<class 'NoneType'>, <class 'dict'>]        9.01    90.99
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4         1128070
# 5         2330502
# 6         2183863
# 7               0

# %%
df_massachusetts.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text       1128070
# pics       2330502
# resp       2183863
# gmap_id          0
# dtype: int64

# %%
duplicados = df_massachusetts[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                   name           time  rating  \
# 41       114014776689591294366         Daniel Hedberg  1565751951804       5
# 42       105194032365179721165           walid makouk  1624586931166       5
# 43       101024502994161709774  Michelle Ubiñas Lopez  1611649076280       5
# 48       104060787771961850802               Buf falo  1553179642220       5
# 223      104028294712254594041            Taryn Colón  1620496883971       5
# ...                        ...                    ...            ...     ...
# 2399971  108853198243721502608     Jeremias Caraballo  1522707432644       5
# 2399972  109325593375610135069             Dave Grimm  1520030955332       4
# 2399973  109961978655018633912         David Churbuck  1508353600658       4
# 2399974  117906650713034984048                Kevin M  1515010052915       5
# 2399975  108000401105585109531          Lauri Koorits  1527973838699       5
#
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_massachusetts, column)
    print("-"*66)
# Out:
# Total de outliers en time: 17166 de 2400000 registros -- 0.72 %
# ------------------------------------------------------------------
# Total de outliers en rating: 101490 de 2400000 registros -- 4.23 %
# ------------------------------------------------------------------

# %% [markdown]
# Michigan

# %%
df_michigan = hp.merge_dataframes(r"data-states\review-Michigan",15)

# %%
hp.data_overview(df_michigan)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       57.95    42.05
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.39    97.61
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       13.53    86.47
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          946194
# 5         2196242
# 6         1945535
# 7               0

# %%
df_michigan.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        946194
# pics       2196242
# resp       1945535
# gmap_id          0
# dtype: int64

# %%
duplicados = df_michigan[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                  name           time  rating  \
# 152      103510375724314058810     Steve Kasianowicz  1564285689766       5
# 154      101622452308139364134  Zech Cowles (Zfyant)  1490200074244       5
# 155      112204923512703999032                Rob Br  1486906935894       5
# 199      100594355772927108105           Beaver Xing  1612224954723       5
# 270      115963223130323951273                   S M  1541396363214       5
# ...                        ...                   ...            ...     ...
# 1993992  100718594959653737518          Ranae Spiers  1480357651644       4
# 1993993  114264016605855459260          Nathan Smith  1556558090342       5
# 1993994  107584118242834308020          Angie Carson  1531584808182       3
# 1993995  117704615440876791815                  Gwen  1525988262405       4
# 1993996  102078825508368690911            Sporty6977  1564276252118       5
#
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_michigan, column)
    print("-"*66)
# Out:
# Total de outliers en time: 14387 de 2250000 registros -- 0.64 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 2250000 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Minnesota

# %%
df_minnesota = hp.merge_dataframes(r"data-states\review-Minnesota",12)

# %%
hp.data_overview(df_minnesota)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       56.74    43.26
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.71    97.29
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       13.16    86.84
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          778590
# 5         1751269
# 6         1563067
# 7               0

# %%
df_minnesota.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        778590
# pics       1751269
# resp       1563067
# gmap_id          0
# dtype: int64

# %%
duplicados = df_minnesota[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                       user_id          name           time  rating  \
# 115     116057270886998703695  amber seaver  1552602494386       5
# 116     104403085979335744190        Z Gens  1517971695018       5
# 200     102851684893658451044   Tina Pickar  1629636239542       4
# 439     104997547151906397891  Walker Smith  1630612279228       5
# 443     106563548453799325850   Robert Cray  1495052497723       5
# ...                       ...           ...            ...     ...
# 727867  116010030352568641500    colt freye  1534213085691       5
# 727869  116471753429512823105     Tyrone Jr  1556307794131       2
# 727874  116967220489817340818  Aura Arounds  1357598314752       3
# 727888  109293554385300615742       Amy Ren  1513861822204       1
# 727889  106969681217885447030    Keiona Guy  1577478558253       5
#
#                                                      text  \
# 115     Amber was awesome to work with. We definitely ...
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_minnesota, column)
    print("-"*66)
# Out:
# Total de outliers en time: 13139 de 1800000 registros -- 0.73 %
# ------------------------------------------------------------------
# Total de outliers en rating: 84686 de 1800000 registros -- 4.7 %
# ------------------------------------------------------------------

# %% [markdown]
# Mississippi

# %%
df_mississippi = hp.merge_dataframes(r"data-states\review-Mississippi",14)

# %%
hp.data_overview(df_mississippi)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       52.01    47.99
# 5         pics  [<class 'NoneType'>, <class 'list'>]        1.72    98.28
# 6         resp  [<class 'NoneType'>, <class 'dict'>]        9.51    90.49
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          945880
# 5         1937258
# 6         1783728
# 7               0

# %%
df_mississippi.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        945880
# pics       1937258
# resp       1783728
# gmap_id          0
# dtype: int64

# %%
duplicados = df_mississippi[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id                     name           time  \
# 151      102432455585978368065             Toni Kitchin  1614915844840
# 495      105075586425456810537             John Johnson  1551119446619
# 618      113840102005864189100  EsterAngela WeltyHarvey  1559831529677
# 883      109818626919525938711           Patti Strother  1598023328629
# 884      108988793398570508962           Hilda Forister  1492212551217
# ...                        ...                      ...            ...
# 1835429  102146027142817653894           Ahart O Wilson  1583799400747
# 1835586  109543600229392375185        William Hendricks  1485787888196
# 1835587  117017701529007744096          Dennis Bardwell  1529859224354
# 1836040  107376049446481226135            Sharitte Hill  1580318007417
# 1836042  101237745984620303588              Bill Howell  1570376108099
#
#          rating                                               text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_mississippi, column)
    print("-"*66)
# Out:
# Total de outliers en time: 5870 de 1971181 registros -- 0.3 %
# ------------------------------------------------------------------
# Total de outliers en rating: 0 de 1971181 registros -- 0.0 %
# ------------------------------------------------------------------

# %% [markdown]
# Missouri

# %%
df_missouri = hp.merge_dataframes(r"data-states\review-Missouri",11)

# %%
hp.data_overview(df_missouri)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       57.74    42.26
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.41    97.59
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       13.99    86.01
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          697268
# 5         1610277
# 6         1419241
# 7               0

# %%
df_missouri.isna().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text        697268
# pics       1610277
# resp       1419241
# gmap_id          0
# dtype: int64

# %%
duplicados = df_missouri[["user_id","name","time","rating","text","gmap_id"]]
duplicados[duplicados.duplicated()]
# Out:
#                        user_id              name           time  rating  \
# 30       106723975708987520303      Sarah Kaiser  1565138132613       5
# 32       100137989359768429387       Shane Field  1531247856637       4
# 45       106287504540119191780        Bre Raquel  1506975599650       1
# 53       100950365026733228401  maria de la cruz  1529558476439       1
# 82       109068734165311939491         B Edwards  1545112501663       3
# ...                        ...               ...            ...     ...
# 1090121  116321171406375500853       Sue Slavens  1541428946338       5
# 1090122  110639188117874745078       Vicki Smith  1506829863284       5
# 1090123  110580765244973331464     Nancy Ritchie  1534709509616       5
# 1090124  110081785465274006248       Kathy Brown  1569883210715       5
# 1090125  117823083389737291477    Richard Bruner  1561260526466       5
#
#                                                       text  \
# ...

# %%
outliers_columns = ['time','rating']

for column in outliers_columns:
    hp.outliers_percentage(df_missouri, column)
    print("-"*66)
# Out:
# Total de outliers en time: 9208 de 1650000 registros -- 0.56 %
# ------------------------------------------------------------------
# Total de outliers en rating: 85923 de 1650000 registros -- 5.21 %
# ------------------------------------------------------------------

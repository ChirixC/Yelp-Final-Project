# %%
import helper as hp
import pandas as pd

# %% [markdown]
# Ingesta de todos los archivos JSON por batch para hacer un merge de todos los JSON por cada estado

# %%
df_Rhode_Island = hp.merge_dataframes('data/Rhode_Island',6)
df_South_Carolina = hp.merge_dataframes('data/South_Carolina',14)
df_South_Dakota = hp.merge_dataframes('data/South_Dakota',5)
df_Tennessee = hp.merge_dataframes('data/Tennessee',12)
df_Texas = hp.merge_dataframes('data/Texas',16)
df_Utah = hp.merge_dataframes('data/Utah',10)
df_Vermont = hp.merge_dataframes('data/Vermont',3)
df_Virginia = hp.merge_dataframes('data/Virginia',12)
df_Washington = hp.merge_dataframes('data/Washington',13)
df_West_Virginia = hp.merge_dataframes('data/West_Virginia',8)
df_Wisconsin = hp.merge_dataframes('data/Wisconsin',12)
df_Wyoming = hp.merge_dataframes('data/Wyoming',3)

# %% [markdown]
# Rhode_Island

# %%
df_Rhode_Island.head()
# Out:
#                  user_id                  name           time  rating  \
# 0  107906906955290728264           Rubia Bella  1601590520320       5
# 1  116735009919665557057       angel olivencia  1602983693555       4
# 2  105746891382332508275       Daniel Reggiani  1603064156784       5
# 3  116728227707437984696  Joseph “Joe” Solomon  1600710962505       5
# 4  111306322994544036169        Julio Robinson  1601408236165       5
#
#                                   text  pics  \
# 0  Very good! Will eat here again! ☺️😍  None
# 1           Not bad place... good food  None
# 2                     Really good food  None
# 3                Great people and food  None
# 4                                 None  None
#
#                                                 resp  \
# 0  {'time': 1602371857761, 'text': 'Hope to see y...
# 1                                               None
# 2                                               None
# ...

# %%
hp.data_overview(df_Rhode_Island)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       52.16    47.84
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.53    97.47
# 6         resp  [<class 'dict'>, <class 'NoneType'>]        8.65    91.35
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          425745
# 5          867459
# 6          812984
# 7               0

# %%
df_Rhode_Island = df_Rhode_Island[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Rhode_Island[df_Rhode_Island.duplicated()]
# Out:
#                       user_id             name           time  rating  \
# 12      100287513293945499073    Peter Kenahan  1515432614196       5
# 55      117961873742905959673     subway lover  1623356283949       5
# 118     104650263076683494290     Doriann Leav  1493304527133       5
# 312     107906906955290728264      Rubia Bella  1601590520320       5
# 313     116735009919665557057  angel olivencia  1602983693555       4
# ...                       ...              ...            ...     ...
# 803209  109844726800067915197     Diane Coccia  1561476535724       5
# 803213  108188846793072409445    Vicki Brodeur  1505857921363       4
# 803220  102648732837572089296    Augustine Wie  1496557741030       4
# 803222  112034686609283635444    Branden Diniz  1490235285062       3
# 803226  108932598687147151209     Tc Pendarvis  1481232737947       5
#
#                                                      text  \
# 12         Top notch agency. Excellent staff and service.
# ...

# %%
hp.outliers_percentage(df_Rhode_Island,'rating')
# Out:
# Total de outliers en rating: 34595 de 890006 registros -- 3.89 %

# %% [markdown]
# South_Carolina

# %%
df_South_Carolina.head(2)
# Out:
#                  user_id             name           time  rating  \
# 0  108990006967932198283     Pamela Poole  1611327187871       4
# 1  115786965178279773121  Cleveland Grant  1520462369713       5
#
#                                                 text  \
# 0  They were very informative  about  the product...
# 1  Great Gun Shop!!! Best local shop you will fin...
#
#                                                 pics  resp  \
# 0                                               None  None
# 1  [{'url': ['https://lh5.googleusercontent.com/p...  None
#
#                                  gmap_id
# 0  0x8856e3dd768d3649:0xb38593eb55374673
# 1  0x8856e3dd768d3649:0xb38593eb55374673

# %%
hp.data_overview(df_South_Carolina)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       56.62    43.38
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.47    97.53
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       13.45    86.55
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          910955
# 5         2048031
# 6         1817499
# 7               0

# %%
df_South_Carolina = df_South_Carolina[['user_id','name','time','rating','text','gmap_id']]

# %%
df_South_Carolina[df_South_Carolina.duplicated()]
# Out:
#                        user_id                      name           time  \
# 187      102769574805507102511              RachelOberst  1595932185486
# 453      115280122166414635313  SHAWNLAWN com SHAYS, LLC  1607648302430
# 454      103740281785594369905             bill Butteris  1613235122186
# 458      113419268133659713390             Justin Harvey  1529938020853
# 459      106082451109203404554           Kelly Greenhill  1470281753402
# ...                        ...                       ...            ...
# 838990   107713689583349302481         Lanita Formyduval  1530641492578
# 838991   112317667240800936639                  Thomas D  1550681217729
# 838992   110118384113538971132              Debbie White  1502025086618
# 838993   113926418048775217926    Jeannette D'Abbondanza  1555102613772
# 2027859  104697030044992536761              Brenda Hicks  1552856605434
#
#          rating                                               text  \
# ...

# %%
hp.outliers_percentage(df_South_Carolina,'rating')
# Out:
# Total de outliers en rating: 0 de 2100000 registros -- 0.0 %

# %% [markdown]
# South_Dakota

# %%
df_South_Dakota.head(2)
# Out:
#                  user_id         name           time  rating  \
# 0  103563353519118158246    Peri Gray  1516122675780       5
# 1  101824980797027243148  Suzy Berndt  1532922350314       5
#
#                                     text  pics  resp  \
# 0  Great place to care for our children.  None  None
# 1                    Th sw y are so nice  None  None
#
#                                  gmap_id
# 0  0x532af45db8f30779:0xd9be9359f1e56178
# 1  0x532af45db8f30779:0xd9be9359f1e56178

# %%
hp.data_overview(df_South_Dakota)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       51.57    48.43
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.35    97.65
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       12.36    87.64
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          325966
# 5          657233
# 6          589840
# 7               0

# %%
df_South_Dakota = df_South_Dakota[['user_id','name','time','rating','text','gmap_id']]

# %%
df_South_Dakota[df_South_Dakota.duplicated()]
# Out:
#                       user_id               name           time  rating  \
# 152     110267618768188007354    Sonja Shoemaker  1574388154119       5
# 154     118368092544999686390  Pamela Weidenbach  1606179799832       5
# 158     107677990495140727146      Jessica Bruce  1631025025528       2
# 290     103563353519118158246          Peri Gray  1516122675780       5
# 291     101824980797027243148        Suzy Berndt  1532922350314       5
# ...                       ...                ...            ...     ...
# 584374  100603413691834918533        Roxan Smith  1530633992215       3
# 584390  109489593497644898309              Ronne  1505622560092       5
# 584393  103640177519942801616    Colin Schindler  1494165419487       5
# 584400  110521488560536685061    Sonia Sepulveda  1591240506484       5
# 584647  101792599737564814522         Ryan Smith  1502329830120       4
#
#                                                      text  \
# ...

# %%
hp.outliers_percentage(df_South_Dakota,'rating')
# Out:
# Total de outliers en rating: 23492 de 673048 registros -- 3.49 %

# %% [markdown]
# Tennessee

# %%
df_Tennessee.head(2)
# Out:
#                  user_id          name           time  rating  \
# 0  118288383279870497662   Ally Medina  1567349037857       1
# 1  113084676538676678822  Nikki Thomas  1476897445568       5
#
#                                                 text  pics  \
# 0  I have been taking my daughter here since 2015...  None
# 1  We switched from Dr.Henschel at Tennessee Pedi...  None
#
#                                                 resp  \
# 0  {'time': 1567368090513, 'text': 'All of the pr...
# 1                                               None
#
#                                  gmap_id
# 0  0x88640cea7d985e0b:0xf214c6bf1d01be6c
# 1  0x88640cea7d985e0b:0xf214c6bf1d01be6c

# %%
hp.data_overview(df_Tennessee)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       56.72    43.28
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.43    97.57
# 6         resp  [<class 'dict'>, <class 'NoneType'>]       14.15    85.85
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          779043
# 5         1756208
# 6         1545223
# 7               0

# %%
df_Tennessee = df_Tennessee[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Tennessee[df_Tennessee.duplicated()]
# Out:
#                        user_id                 name           time  rating  \
# 7        118288383279870497662          Ally Medina  1567349037857       1
# 12       106107522724371265059              Elana J  1536611256348       5
# 14       108989653364110837335     Athraa Altameemi  1430772187048       1
# 147      116203044939357300362          Jerrod Wirt  1596497159031       4
# 218      100786272959418290036  Stephanie Bubrowski  1627859230742       1
# ...                        ...                  ...            ...     ...
# 1120791  100192424500988546867         Denny Hooven  1611203513496       5
# 1120792  113768634019197460720            Ron Smith  1558482632486       5
# 1120793  117883605076767272178     charles williams  1542049670300       5
# 1120794  102676636893134551256        Timmy Roberts  1524423196208       5
# 1471918  117351641842798304307        Jeremy Crouch  1559616553791       4
#
#                                                       text  \
# ...

# %%
hp.outliers_percentage(df_Tennessee,'rating')
# Out:
# Total de outliers en rating: 0 de 1800000 registros -- 0.0 %

# %% [markdown]
# Texas

# %%
df_Texas.head(2)
# Out:
#                  user_id            name           time  rating  \
# 0  110545299078970317447  Kimberly Feger  1625431734826       5
# 1  103619788097506115343   Briana Streit  1568336283913       2
#
#                                                 text  pics  resp  \
# 0  The pharmacist, Erin, is phenomenal. She was s...  None  None
# 1  I gave them 2 stars because they offer prescri...  None  None
#
#                                  gmap_id
# 0  0x864c3998b8d8dc83:0x57ffabe1e2322320
# 1  0x864c3998b8d8dc83:0x57ffabe1e2322320

# %%
hp.data_overview(df_Texas)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       59.98    40.02
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.97    97.03
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       16.32    83.68
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          919209
# 5         2228515
# 6         1921986
# 7               0

# %%
df_Texas = df_Texas[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Texas[df_Texas.duplicated()]
# Out:
#                        user_id              name           time  rating  \
# 167      107867231575174138918      Sarah Miller  1585167998228       5
# 168      103865094732835532683    Terry Adkisson  1570205288482       5
# 232      113598715794307025957       Tony Stillo  1627587914420       5
# 251      103451418282688721030      Debbie Lopez  1576917067267       5
# 254      114989540535515468977   David Hutchings  1608253942649       5
# ...                        ...               ...            ...     ...
# 2249985  104118913570791830230          La Gorda  1553260828587       3
# 2249986  100500087744996089363    lisa cherrypie  1555759846561       5
# 2249994  102963788471912959695        bev franks  1549692414861       5
# 2249995  116567962160235224438  Bridget Connolly  1571266253130       5
# 2249997  113818620790090141548       Amani Sofia  1484315775563       5
#
#                                                       text  \
# ...

# %%
hp.outliers_percentage(df_Texas,'rating')
# Out:
# Total de outliers en rating: 0 de 2296824 registros -- 0.0 %

# %% [markdown]
# Utah

# %%
df_Utah.head(2)
# Out:
#                  user_id              name           time  rating  \
# 0  111182595077674366891        Liz W Poch  1627085008811       5
# 1  117689170846448249054  Mario D'Ambrosio  1626437133578       1
#
#                                                 text  pics  resp  \
# 0  Paige is the best! Everyone at this branch is ...  None  None
# 1  I have updated my systems on two titles for ca...  None  None
#
#                                  gmap_id
# 0  0x87528767d0ec0e4d:0x7a2f1637a6fb6925
# 1  0x87528767d0ec0e4d:0x7a2f1637a6fb6925

# %%
hp.data_overview(df_Utah)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       62.40    37.60
# 5         pics  [<class 'NoneType'>, <class 'list'>]        3.29    96.71
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       16.77    83.23
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          564060
# 5         1450620
# 6         1248385
# 7               0

# %%
df_Utah = df_Utah[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Utah[df_Utah.duplicated()]
# Out:
#                       user_id                 name           time  rating  \
# 223     104676021109517424366           Michelle M  1607495692896       5
# 226     118056861651460574638         Sheila Agnew  1579829155203       5
# 228     113661601843652031643       Bethany McLean  1580148330489       5
# 236     114997146468966969416  Geoffrey Huntzinger  1620248245257       5
# 351     116447018160190608299              Jffstcy  1595013249580       5
# ...                       ...                  ...            ...     ...
# 623506  117014530408913873605       Big John Crews  1554819999958       5
# 623549  110766924732126527830       Mark Runolfson  1520376803357       1
# 623637  113131919463851162145            Jon Kasai  1557786451376       5
# 623638  103538718455362001258               rick A  1561675142774       5
# 623645  116099485616760649694           Jennifer B  1392763159252       5
#
#                                                      text  \
# ...

# %%
hp.outliers_percentage(df_Utah,'rating')
# Out:
# Total de outliers en rating: 0 de 1500000 registros -- 0.0 %

# %% [markdown]
# Vermont

# %%
df_Vermont.head(2)
# Out:
#                  user_id           name           time  rating  \
# 0  118026874392842649478  rebecca kerns  1620085852324       5
# 1  101532740754036204131  Peter DeForge  1580309946474       5
#
#                                                 text  pics  \
# 0      Always done right from wood stove to screens!  None
# 1  A great company to work with.  Their sales and...  None
#
#                                                 resp  \
# 0  {'time': 1620087641504, 'text': 'Good Evening,...
# 1  {'time': 1580320228721, 'text': 'Good Afternoo...
#
#                                  gmap_id
# 0  0x89e02445cb9db457:0x37f42bff4edf7a43
# 1  0x89e02445cb9db457:0x37f42bff4edf7a43

# %%
hp.data_overview(df_Vermont)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       54.87    45.13
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.97    97.03
# 6         resp  [<class 'dict'>, <class 'NoneType'>]        8.26    91.74
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          146557
# 5          315074
# 6          297887
# 7               0

# %%
df_Vermont = df_Vermont[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Vermont[df_Vermont.duplicated()]
# Out:
#                       user_id             name           time  rating  \
# 128     118026874392842649478    rebecca kerns  1620085852324       5
# 129     101532740754036204131    Peter DeForge  1580309946474       5
# 130     115404122636203550540    Chad Goulette  1605195974445       5
# 131     104789336434407408181  Mark LaFountain  1593005848256       5
# 132     108980665975608069965           Jeff R  1582059996120       5
# ...                       ...              ...            ...     ...
# 310825  102705089064804721245       Eric Adler  1467383623808       5
# 310829  102664784364025240989      Benjamin Z.  1510026691287       5
# 311165  102579984686539862885        Robb Kidd  1511550540180       4
# 311179  107063283865460850703      Gary Holmes  1569170392437       5
# 311195  104794509811723001172      George Rice  1529719031010       5
#
#                                                      text  \
# 128         Always done right from wood stove to screens!
# ...

# %%
hp.outliers_percentage(df_Vermont,'rating')
# Out:
# Total de outliers en rating: 10249 de 324725 registros -- 3.16 %

# %% [markdown]
# Virginia

# %%
df_Virginia.head(2)
# Out:
#                  user_id            name           time  rating  \
# 0  111603605060980047815      Jessie Lee  1581455645898       5
# 1  106278681944354596566  Brittany Janis  1612044004790       2
#
#                              text  pics  \
# 0  I loved Rita!! She was awesome  None
# 1      Expensive to do taxes here  None
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1614371539737, 'text': 'Thank you for...
#
#                                  gmap_id
# 0  0x89b1af6550d33595:0x8fb8874b8aa57e3f
# 1  0x89b1af6550d33595:0x8fb8874b8aa57e3f

# %%
hp.data_overview(df_Virginia)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       57.11    42.89
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.77    97.23
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       13.53    86.47
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          712868
# 5         1616020
# 6         1437240
# 7               0

# %%
df_Virginia = df_Virginia[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Virginia[df_Virginia.duplicated()]
# Out:
#                        user_id            name           time  rating  \
# 79       115935390405186874646   Bobby Hagwood  1525645860313       5
# 290      109255601614271896674   Thomas Martin  1519666775745       5
# 444      114126536219717777502       Anonymous  1594731046726       5
# 459      108413923508679207724             D S  1544723437119       5
# 460      114220477965249242623   Kaitlin Price  1509133875696       5
# ...                        ...             ...            ...     ...
# 1114618  116258473206712882600    Sarah Stroop  1590169405418       5
# 1114753  111511912771578256827    Willie Davis  1573582937863       5
# 1114754  104337608656327024779     George Wade  1541304918913       5
# 1115163  102987328892571243242           Dutch  1555725098315       5
# 1377356  110336405781916645521  Kathie Conaway  1555930452598       5
#
#                                                       text  \
# 79                          Friendly people and nice work.
# ...

# %%
hp.outliers_percentage(df_Virginia,'rating')
# Out:
# Total de outliers en rating: 0 de 1662059 registros -- 0.0 %

# %% [markdown]
# Washington

# %%
df_Washington.head(2)
# Out:
#                  user_id           name           time  rating  \
# 0  103093043835388050629  Casper Steele  1626907411534       2
# 1  111014066796803341223      Judy Maes  1613028426989       5
#
#                                                 text  pics  resp  \
# 0  Drivers say security has bathroom key. Securit...  None  None
# 1  It's a CTRAN transit center with schedules to ...  None  None
#
#                                  gmap_id
# 0  0x5495ae7d3bf7d097:0xbcbc06152a3ccebc
# 1  0x5495ae7d3bf7d097:0xbcbc06152a3ccebc

# %%
hp.data_overview(df_Washington)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       59.11    40.89
# 5         pics  [<class 'NoneType'>, <class 'list'>]        3.85    96.15
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       11.53    88.47
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          794099
# 5         1867160
# 6         1718196
# 7               0

# %%
df_Washington = df_Washington[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Washington[df_Washington.duplicated()]
# Out:
#                        user_id           name           time  rating  \
# 24       108990370661074114522   Jake Stahnke  1607835364291       5
# 27       103286334083735294545     Paul Felix  1581994848419       5
# 283      102125666410634612565    ryan pruden  1620940926947       5
# 288      108169694065571389630      Eric Bean  1573759478704       5
# 293      113600367683074552649       khrispin  1601322515098       5
# ...                        ...            ...            ...     ...
# 1193729  107053312377812140262   James T. Rho  1446179698137       5
# 1193791  109482957376760257489  Darin Schultz  1424903684371       1
# 1193910  109477474002615461958     gm Borillo  1532203733527       5
# 1846658  116165394179584549888  Abigail Moore  1559185091931       5
# 1871906  106460595842770240739  Dale Demarais  1566773979576       5
#
#                                                       text  \
# 24       This place is amazing. Incredible artists acro...
# ...

# %%
hp.outliers_percentage(df_Washington,'rating')
# Out:
# Total de outliers en rating: 99321 de 1942020 registros -- 5.11 %

# %% [markdown]
# West_Virginia

# %%
df_West_Virginia.head(2)
# Out:
#                  user_id          name           time  rating  \
# 0  104649161250561778800   Pam Holcomb  1557935316444       4
# 1  100934414726750280374  Cheryl Norga  1532897953993       5
#
#                                                 text  pics  resp  \
# 0  Nice personnel and atmosphere and have done bu...  None  None
# 1  Maggie is awesome..very sweet & helpful.\nLadi...  None  None
#
#                                  gmap_id
# 0  0x884955486c37d473:0x1b1f0907f74deee5
# 1  0x884955486c37d473:0x1b1f0907f74deee5

# %%
hp.data_overview(df_West_Virginia)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       51.76    48.24
# 5         pics  [<class 'NoneType'>, <class 'list'>]        1.72    98.28
# 6         resp  [<class 'NoneType'>, <class 'dict'>]        8.62    91.38
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          521110
# 5         1061745
# 6          987184
# 7               0

# %%
df_West_Virginia = df_West_Virginia[['user_id','name','time','rating','text','gmap_id']]

# %%
df_West_Virginia[df_West_Virginia.duplicated()]
# Out:
#                        user_id              name           time  rating  \
# 474      108330773479523125680    Jonathan Smith  1603491380061       5
# 615      112993535374624081465      Don Springer  1607537690515       5
# 619      113644562720143225541       Terra Gould  1494609225030       5
# 645      104649161250561778800       Pam Holcomb  1557935316444       4
# 646      100934414726750280374      Cheryl Norga  1532897953993       5
# ...                        ...               ...            ...     ...
# 1029342  102699481454755918912  robert raspperry  1523477037667       5
# 1029345  100994112571329509682   Benjamin Taylor  1529790493907       5
# 1029415  113524244859789171808     Callie Miller  1546111168652       5
# 1029417  105939728644823349793     Debbie Pierce  1484839396162       5
# 1029418  109664309847969069447    Autumn Swallie  1350936661425       5
#
#                                                       text  \
# ...

# %%
hp.outliers_percentage(df_West_Virginia,'rating')
# Out:
# Total de outliers en rating: 45130 de 1080333 registros -- 4.18 %

# %% [markdown]
# Wisconsin

# %%
df_Wisconsin.head(2)
# Out:
#                  user_id            name           time  rating  \
# 0  105449565300564768957   Kadence Leigh  1592846644902       3
# 1  108990867128544289815  Jeremy Schafer  1534088176466       1
#
#                                                 text  pics  resp  \
# 0  Fun although a lot of breaks witch sucks and t...  None  None
# 1  Management sucks they don't watch the  kids ha...  None  None
#
#                                  gmap_id
# 0  0x87fd108d3f915a5f:0x2b7132092901f4df
# 1  0x87fd108d3f915a5f:0x2b7132092901f4df

# %%
hp.data_overview(df_Wisconsin)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       55.58    44.42
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.37    97.63
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       12.70    87.30
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          749192
# 5         1646557
# 6         1472242
# 7               0

# %%
df_Wisconsin = df_Wisconsin[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Wisconsin[df_Wisconsin.duplicated()]
# Out:
#                       user_id             name           time  rating  \
# 221     116342819810654238030     Trish Bailey  1570876274683       5
# 222     109992655717796111833     Anne Herbold  1544333149056       5
# 224     110660136459750891097        Seleneies  1509667189584       5
# 233     102479081776799596051     Kelli Ezzell  1623010110345       5
# 237     115683944997284924624       April Lowe  1619832708202       3
# ...                       ...              ...            ...     ...
# 937483  114982246664471758935    Kofi Mayfield  1596677751448       5
# 937484  105085996984291057489  Adria Klucarich  1586890370994       5
# 937485  110901104839660243274        old hippy  1593817103035       5
# 937486  115957662384201995416    Doug Hafemann  1593635203720       5
# 937487  112041046331659929523   Cindie Zehnder  1591727759406       5
#
#                                                      text  \
# 221                They are clean, kind and accommodating
# ...

# %%
hp.outliers_percentage(df_Wisconsin,'rating')
# Out:
# Total de outliers en rating: 74920 de 1686482 registros -- 4.44 %

# %% [markdown]
# Wyoming

# %%
df_Wyoming.head(2)
# Out:
#                  user_id            name           time  rating  \
# 0  111435346941066248277     Jenn Thomas  1602893531994       5
# 1  103613723635264236030  Michelle Barta  1575991509006       5
#
#                                                 text  pics  \
# 0  When knowledge is key and kindness matters, Ni...  None
# 1  The entire team is outstanding! They are profe...  None
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1580484156696, 'text': 'We are lucky ...
#
#                                  gmap_id
# 0  0x8758dd1ca83449d9:0xb6156dcfc5e04c9b
# 1  0x8758dd1ca83449d9:0xb6156dcfc5e04c9b

# %%
hp.data_overview(df_Wyoming)
# Out:
#   nombre_campo                            tipo_datos  NO_nulos_%  nulos_%  \
# 0      user_id                       [<class 'str'>]      100.00     0.00
# 1         name                       [<class 'str'>]      100.00     0.00
# 2         time                       [<class 'int'>]      100.00     0.00
# 3       rating                       [<class 'int'>]      100.00     0.00
# 4         text   [<class 'str'>, <class 'NoneType'>]       54.85    45.15
# 5         pics  [<class 'NoneType'>, <class 'list'>]        2.52    97.48
# 6         resp  [<class 'NoneType'>, <class 'dict'>]       10.28    89.72
# 7      gmap_id                       [<class 'str'>]      100.00     0.00
#
#    nulos_cantidad
# 0               0
# 1               0
# 2               0
# 3               0
# 4          193146
# 5          417007
# 6          383843
# 7               0

# %%
df_Wyoming = df_Wyoming[['user_id','name','time','rating','text','gmap_id']]

# %%
df_Wyoming[df_Wyoming.duplicated()]
# Out:
#                       user_id            name           time  rating  \
# 111     108603137568553056600      Jim Kirsch  1537830138679       3
# 182     111435346941066248277     Jenn Thomas  1602893531994       5
# 183     103613723635264236030  Michelle Barta  1575991509006       5
# 184     113556685435236755030  Bethany Baldes  1626981484302       5
# 185     102235352482458236558    nichole vogt  1583381337082       5
# ...                       ...             ...            ...     ...
# 381875  106538827245350627152  Verna Spradlin  1559442420072       5
# 381876  115944220478789158390  Michaela Crase  1595546332269       5
# 381901  107322485238130152629             Mel  1530844561730       5
# 381970  110995637436482609725      thecoollog  1598760106281       5
# 381977  104344606932152574164     Daniel Snow  1555042594841       5
#
#                                                      text  \
# 111     My wife and I regularly enjoy a cheese burger ...
# ...

# %%
hp.outliers_percentage(df_Wyoming,'rating')
# Out:
# Total de outliers en rating: 17148 de 427808 registros -- 4.01 %

# %% [markdown]
# Salida de los parquets para tener disponibles los archivos

# %%
df_Rhode_Island_ruta = 'data/df_Rhode_Island.parquet'
df_Rhode_Island.to_parquet(df_Rhode_Island_ruta, index=False)

df_South_Carolina_ruta = 'data/df_South_Carolina.parquet'
df_South_Carolina .to_parquet(df_South_Carolina_ruta, index=False)

df_South_Dakota_ruta = 'data/df_South_Dakota.parquet'
df_South_Dakota .to_parquet(df_South_Dakota_ruta, index=False)

df_Tennessee_ruta = 'data/df_Tennessee.parquet'
df_Tennessee .to_parquet(df_Tennessee_ruta, index=False)

df_Texas_ruta = 'data/df_Texas.parquet'
df_Texas.to_parquet(df_Texas_ruta, index=False)

df_Utah_ruta = 'data/df_Utah.parquet'
df_Utah.to_parquet(df_Utah_ruta, index=False)

df_Vermont_ruta = 'data/df_Vermont.parquet'
df_Vermont.to_parquet(df_Vermont_ruta, index=False)

df_Virginia_ruta = 'data/df_Virginia.parquet'
df_Virginia.to_parquet(df_Virginia_ruta, index=False)

df_Washington_ruta = 'data/df_Washington.parquet'
df_Washington.to_parquet(df_Washington_ruta, index=False)

df_West_Virginia_ruta = 'data/df_West_Virginia.parquet'
df_West_Virginia.to_parquet(df_West_Virginia_ruta, index=False)

df_Wisconsin_ruta = 'data/df_Wisconsin.parquet'
df_Wisconsin.to_parquet(df_Wisconsin_ruta, index=False)

df_Wyoming_ruta = 'data/df_Wyoming.parquet'
df_Wyoming.to_parquet(df_Wyoming_ruta, index=False)
